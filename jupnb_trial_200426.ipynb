# %% [markdown]
# GFM:
# **This is so nice**
# I'll now link to
# 1. this is item 1
# 2. this is item 2
#     * and then some bullets
#     * and more
#
# Given the transfer function
#
# $G(s) = \frac{6}{(s+1)(s+2)(s+3)}$

# %%
import numpy as np
print(np.log(10))
# Out:
# 2.302585092994046

# %%
x = [i*0.2 for i in range(500)]
y = [(np.sin(xt))**2 for xt in x]
import matplotlib.pyplot as plt
'''Todo: Change the parameters in the equation and run'''
plt.plot(x,y)
